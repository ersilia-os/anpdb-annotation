# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("anpdb_annotated.tsv", sep="\t")
df.head()
# Out:
#                       inchikey                                    smiles  \
# 0  SNOQQKJRUJUFGR-LHUOGLBJSA-N        C#C/C=C/CCCC#C/C=C/CCCCCCC/C=C/C#C
# 1  BNQBIHGDTJFABJ-ONEGZZNKSA-N           C#C/C=C/CCCC#CC#CC#CCCCCCCC#CCO
# 2  QTBVJKDCVFGFAY-ONEGZZNKSA-N  C#C/C=C/CCCC#CC#CC#CCCCCCCCC#CC(O)C(=O)O
# 3  YAIWKDHSFYJROB-FNORWQNLSA-N                C#C/C=C/CCCC#CC#CCCCCCCC#C
# 4  ODOHBJISRZXRAM-FNORWQNLSA-N               C#C/C=C/CCCC#CCCCCCCCCCCC#C
#
#              name  sa_score_eos9ei3  np_score_eos9yui  ra_score_eos2r5a  \
# 0  aikupikanyne C          3.586327          9.103713          0.379231
# 1  aikupikanyne E          3.705440         10.906775          0.733042
# 2  aikupikanyne F          4.241573         10.062978          0.194252
# 3  aikupikanyne A          3.551816         10.545182          0.650328
# 4  aikupikanyne B          3.113023         10.065693          0.671758
#
#    mw_eos4djh  fsp3_eos4djh  n_lipinski_hba_eos4djh  n_lipinski_hbd_eos4djh  \
# ...

# %%
plt.hist(df["ra_score_eos2r5a"])
plt.title("Retrosynthetic Accessibility Score")
# Out:
# Text(0.5, 1.0, 'Retrosynthetic Accessibility Score')

# %%
plt.hist(df["sa_score_eos9ei3"])
plt.title("Synthetic Accessibility Score")
# Out:
# Text(0.5, 1.0, 'Synthetic Accessibility Score')

# %%
plt.hist(df["np_score_eos9yui"])
plt.title("Natural Product Score")
# Out:
# Text(0.5, 1.0, 'Natural Product Score')

# %%
fig, axs = plt.subplots(1,4, figsize=(20,5))
axs[0].hist(df["mw_eos4djh"])
axs[0].set_title("Molecular Weight")
axs[1].hist(df["qed_eos4djh"])
axs[1].set_title("Chemical beauty (QED)")
axs[2].hist(df["n_lipinski_hba_eos4djh"])
axs[2].set_title("HB-Acceptors")
axs[3].hist(df["n_lipinski_hbd_eos4djh"])
axs[3].set_title("HB-Donors")
# Out:
# Text(0.5, 1.0, 'HB-Donors')
